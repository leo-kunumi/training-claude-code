# %% [markdown]
# # Chapter 6: Precognition (Thinking Step by Step)
#
# - [Lesson](#lesson)
# - [Exercises](#exercises)
# - [Example Playground](#example-playground)
#
# ## Setup
#
# Run the following setup cell to load your API key and establish the `get_completion` helper function.

# %%
# !pip install anthropic

import re
from anthropic import Anthropic
from dotenv import load_dotenv
import os

load_dotenv()
MODEL_NAME = "claude-3-haiku-20240307"
my_api_key = os.getenv("ANTHROPIC_API_KEY")
if "=" in my_api_key:
    my_api_key = my_api_key.split("=")[1]

client = Anthropic(api_key=my_api_key)

def get_completion(prompt: str, system_prompt="", prefill=""):
    message = client.messages.create(
        model=MODEL_NAME,
        max_tokens=2000,
        temperature=0.0,
        system=system_prompt,
        messages=[
          {"role": "user", "content": prompt},
          {"role": "assistant", "content": prefill}
        ]
    )
    return message.content[0].text
# Out:
# Requirement already satisfied: anthropic in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (0.85.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (2.12.5)
# Requirement already satisfied: sniffio in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/leogazevedo/github/leo-kunumi/training-claude-code/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)

# %% [markdown]
# ---
#
# ## Lesson
#
# If someone woke you up and immediately started asking you several complicated questions that you had to respond to right away, how would you do? Probably not as good as if you were given time to **think through your answer first**.
#
# Guess what? Claude is the same way.
#
# **Giving Claude time to think step by step sometimes makes Claude more accurate**, particularly for complex tasks. However, **thinking only counts when it's out loud**. You cannot ask Claude to think but output only the answer - in this case, no thinking has actually occurred.

# %% [markdown]
# ### Examples
#
# In the prompt below, it's clear to a human reader that the second sentence belies the first. But **Claude takes the word "unrelated" too literally**.

# %%
# Prompt
PROMPT = """Is this movie review sentiment positive or negative?

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since the year 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# To improve Claude's response, let's **allow Claude to think things out first before answering**. We do that by literally spelling out the steps that Claude should take in order to process and think through its task. Along with a dash of role prompting, this empowers Claude to understand the review more deeply.

# %%
# System prompt
SYSTEM_PROMPT = "You are a savvy reader of movie reviews."

# Prompt
PROMPT = """Is this review sentiment positive or negative? First, write the best arguments for each side in <positive-argument> and <negative-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))

# %% [markdown]
# **Claude is sometimes sensitive to ordering**. This example is on the frontier of Claude's ability to understand nuanced text, and when we swap the order of the arguments from the previous example so that negative is first and positive is second, this changes Claude's overall assessment to positive.
#
# In most situations (but not all, confusingly enough), **Claude is more likely to choose the second of two options**, possibly because in its training data from the web, second options were more likely to be correct.

# %%
# Prompt
PROMPT = """Is this review sentiment negative or positive? First write the best arguments for each side in <negative-argument> and <positive-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. Unrelatedly, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# **Letting Claude think can shift Claude's answer from incorrect to correct**. It's that simple in many cases where Claude makes mistakes!
#
# Let's go through an example where Claude's answer is incorrect to see how asking Claude to think can fix that.

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956."

# Print Claude's response
print(get_completion(PROMPT))

# %% [markdown]
# Let's fix this by asking Claude to think step by step, this time in `<brainstorm>` tags.

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956. First brainstorm about some actors and their birth years in <brainstorm> tags, then give your answer."

# Print Claude's response
print(get_completion(PROMPT))
# Out:
# Here's a brainstorm of some actors and their birth years:
#
# <brainstorm>
# - Tom Hanks (1956)
# - Denzel Washington (1954)
# - Julia Roberts (1967)
# - Harrison Ford (1942)
# - Meryl Streep (1949)
# </brainstorm>
#
# A famous movie starring an actor born in 1956 is:
#
# Forrest Gump, starring Tom Hanks.

# %% [markdown]
# If you would like to experiment with the lesson prompts without changing any content above, scroll all the way to the bottom of the lesson notebook to visit the [**Example Playground**](#example-playground).

# %% [markdown]
# ---
#
# ## Exercises
# - [Exercise 6.1 - Classifying Emails](#exercise-61---classifying-emails)
# - [Exercise 6.2 - Email Classification Formatting](#exercise-62---email-classification-formatting)

# %% [markdown]
# ### Exercise 6.1 - Classifying Emails
# In this exercise, we'll be instructing Claude to sort emails into the following categories:
# - (A) Pre-sale question
# - (B) Broken or defective item
# - (C) Billing question
# - (D) Other (please explain)
#
# For the first part of the exercise, change the `PROMPT` to **make Claude output the correct classification and ONLY the classification**. Your answer needs to **include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category**.
#
# Refer to the comments beside each email in the `EMAILS` list to know which category that email should be classified under.

# %%
# Prompt template with a placeholder for the variable content
PROMPT = """Please classify this email as either folowing the category: {email}

- (A) Pre-sale question
- (B) Broken or defective item
- (C) Billing question
- (D) Other (please explain)

 Your answer needs to include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
"""

# Prefill for Claude's response, if any
PREFILL = ""

# Variable content stored as a list
EMAILS = [
    "Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.", # (B) Broken or defective item
    "Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?", # (A) Pre-sale question OR (D) Other (please explain)
    "I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???", # (C) Billing question
    "How did I get here I am not good with computer.  Halp." # (D) Other (please explain)
]

# Correct categorizations stored as a list of lists to accommodate the possibility of multiple correct categorizations per email
ANSWERS = [
    ["B"],
    ["A","D"],
    ["C"],
    ["D"]
]

# Dictionary of string values for each category to be used for regex grading
REGEX_CATEGORIES = {
    "A": "A\) P",
    "B": "B\) B",
    "C": "C\) B",
    "D": "D\) O"
}

# Iterate through list of emails
for i,email in enumerate(EMAILS):
    
    # Substitute the email text into the email placeholder variable
    formatted_prompt = PROMPT.format(email=email)
   
    # Get Claude's response
    response = get_completion(formatted_prompt, prefill=PREFILL)

    # Grade Claude's response
    grade = any([bool(re.search(REGEX_CATEGORIES[ans], response)) for ans in ANSWERS[i]])
    
    # Print Claude's response
    print("--------------------------- Full prompt with variable substutions ---------------------------")
    print("USER TURN")
    print(formatted_prompt)
    print("\nASSISTANT TURN")
    print(PREFILL)
    print("\n------------------------------------- Claude's response -------------------------------------")
    print(response)
    print("\n------------------------------------------ GRADING ------------------------------------------")
    print("This exercise has been correctly solved:", grade, "\n\n\n\n\n\n")
# Out:
# <>:33: SyntaxWarning: invalid escape sequence '\)'
# <>:34: SyntaxWarning: invalid escape sequence '\)'
# <>:35: SyntaxWarning: invalid escape sequence '\)'
# <>:36: SyntaxWarning: invalid escape sequence '\)'
# <>:33: SyntaxWarning: invalid escape sequence '\)'
# <>:34: SyntaxWarning: invalid escape sequence '\)'
# <>:35: SyntaxWarning: invalid escape sequence '\)'
# <>:36: SyntaxWarning: invalid escape sequence '\)'
# /tmp/ipykernel_416665/966674028.py:33: SyntaxWarning: invalid escape sequence '\)'
#   "A": "A\) P",
# /tmp/ipykernel_416665/966674028.py:34: SyntaxWarning: invalid escape sequence '\)'
#   "B": "B\) B",
# /tmp/ipykernel_416665/966674028.py:35: SyntaxWarning: invalid escape sequence '\)'
#   "C": "C\) B",
# /tmp/ipykernel_416665/966674028.py:36: SyntaxWarning: invalid escape sequence '\)'
#   "D": "D\) O"
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either folowing the category: Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.
#
# - (A) Pre-sale question
# - (B) Broken or defective item
# - (C) Billing question
# - (D) Other (please explain)
#
#  Your answer needs to include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# (B) Broken or defective item
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
# /tmp/ipykernel_416665/966674028.py:33: SyntaxWarning: invalid escape sequence '\)'
#   "A": "A\) P",
# /tmp/ipykernel_416665/966674028.py:34: SyntaxWarning: invalid escape sequence '\)'
#   "B": "B\) B",
# /tmp/ipykernel_416665/966674028.py:35: SyntaxWarning: invalid escape sequence '\)'
#   "C": "C\) B",
# /tmp/ipykernel_416665/966674028.py:36: SyntaxWarning: invalid escape sequence '\)'
#   "D": "D\) O"
# /tmp/ipykernel_416665/966674028.py:33: SyntaxWarning: invalid escape sequence '\)'
#   "A": "A\) P",
# /tmp/ipykernel_416665/966674028.py:34: SyntaxWarning: invalid escape sequence '\)'
#   "B": "B\) B",
# /tmp/ipykernel_416665/966674028.py:35: SyntaxWarning: invalid escape sequence '\)'
#   "C": "C\) B",
# /tmp/ipykernel_416665/966674028.py:36: SyntaxWarning: invalid escape sequence '\)'
#   "D": "D\) O"
# /tmp/ipykernel_416665/966674028.py:33: SyntaxWarning: invalid escape sequence '\)'
#   "A": "A\) P",
# /tmp/ipykernel_416665/966674028.py:34: SyntaxWarning: invalid escape sequence '\)'
#   "B": "B\) B",
# /tmp/ipykernel_416665/966674028.py:35: SyntaxWarning: invalid escape sequence '\)'
#   "C": "C\) B",
# /tmp/ipykernel_416665/966674028.py:36: SyntaxWarning: invalid escape sequence '\)'
#   "D": "D\) O"
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either folowing the category: Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?
#
# - (A) Pre-sale question
# - (B) Broken or defective item
# - (C) Billing question
# - (D) Other (please explain)
#
#  Your answer needs to include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# (D) Other (please explain)
#
# The email does not fall under any of the given categories. It is a question about the intended use of a Mixmaster 4000 appliance, whether it can be used for mixing paint or if it is only meant for mixing food.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either folowing the category: I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???
#
# - (A) Pre-sale question
# - (B) Broken or defective item
# - (C) Billing question
# - (D) Other (please explain)
#
#  Your answer needs to include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# (C) Billing question
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# Please classify this email as either folowing the category: How did I get here I am not good with computer.  Halp.
#
# - (A) Pre-sale question
# - (B) Broken or defective item
# - (C) Billing question
# - (D) Other (please explain)
#
#  Your answer needs to include the letter (A - D) of the correct choice, with the parentheses, as well as the name of the category.
#
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# (D) Other (please explain)
#
# The email you described falls under the category "How did I get here I am not good with computer. Halp." This category is not one of the options provided (A-C), so the correct answer is (D) Other.
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_6_1_hint; print(exercise_6_1_hint)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from hints import exercise_6_1_hint; print(exercise_6_1_hint)
#
# ModuleNotFoundError: No module named 'hints'

# %% [markdown]
# Still stuck? Run the cell below for an example solution.

# %%
from hints import exercise_6_1_solution; print(exercise_6_1_solution)

# %% [markdown]
# ### Exercise 6.2 - Email Classification Formatting
# In this exercise, we're going to refine the output of the above prompt to yield an answer formatted exactly how we want it.
#
# Use your favorite output formatting technique to make Claude wrap JUST the letter of the correct classification in `<answer></answer>` tags. For instance, the answer to the first email should contain the exact string `<answer>B</answer>`.
#
# Refer to the comments beside each email in the `EMAILS` list if you forget which letter category is correct for each email.

# %%
# Prompt template with a placeholder for the variable content
PROMPT = """User: Please classify this email into the following categories: {email}

Do not include any extra words except the category. Think step by step before you answer.

<categories>
(A) Pre-sale question
(B) Broken or defective item
(C) Billing question
(D) Other (please explain)
</categories>

Answer with only the letter of the answer wrapped in <answer> tags, such as <answer>B</answer>."""

# Prefill for Claude's response, if any
PREFILL = ""

# Variable content stored as a list
EMAILS = [
    "Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.", # (B) Broken or defective item
    "Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?", # (A) Pre-sale question OR (D) Other (please explain)
    "I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???", # (C) Billing question
    "How did I get here I am not good with computer.  Halp." # (D) Other (please explain)
]

# Correct categorizations stored as a list of lists to accommodate the possibility of multiple correct categorizations per email
ANSWERS = [
    ["B"],
    ["A","D"],
    ["C"],
    ["D"]
]

# Dictionary of string values for each category to be used for regex grading
REGEX_CATEGORIES = {
    "A": "<answer>A</answer>",
    "B": "<answer>B</answer>",
    "C": "<answer>C</answer>",
    "D": "<answer>D</answer>"
}

# Iterate through list of emails
for i,email in enumerate(EMAILS):
    
    # Substitute the email text into the email placeholder variable
    formatted_prompt = PROMPT.format(email=email)
   
    # Get Claude's response
    response = get_completion(formatted_prompt, prefill=PREFILL)

    # Grade Claude's response
    grade = any([bool(re.search(REGEX_CATEGORIES[ans], response)) for ans in ANSWERS[i]])
    
    # Print Claude's response
    print("--------------------------- Full prompt with variable substutions ---------------------------")
    print("USER TURN")
    print(formatted_prompt)
    print("\nASSISTANT TURN")
    print(PREFILL)
    print("\n------------------------------------- Claude's response -------------------------------------")
    print(response)
    print("\n------------------------------------------ GRADING ------------------------------------------")
    print("This exercise has been correctly solved:", grade, "\n\n\n\n\n\n")
# Out:
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# User: Please classify this email into the following categories: Hi -- My Mixmaster4000 is producing a strange noise when I operate it. It also smells a bit smoky and plasticky, like burning electronics.  I need a replacement.
#
# Do not include any extra words except the category. Think step by step before you answer.
#
# <categories>
# (A) Pre-sale question
# (B) Broken or defective item
# (C) Billing question
# (D) Other (please explain)
# </categories>
#
# Answer with only the letter of the answer wrapped in <answer> tags, such as <answer>B</answer>.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# After analyzing the email, the appropriate category is:
#
# <answer>B</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# User: Please classify this email into the following categories: Can I use my Mixmaster 4000 to mix paint, or is it only meant for mixing food?
#
# Do not include any extra words except the category. Think step by step before you answer.
#
# <categories>
# (A) Pre-sale question
# (B) Broken or defective item
# (C) Billing question
# (D) Other (please explain)
# </categories>
#
# Answer with only the letter of the answer wrapped in <answer> tags, such as <answer>B</answer>.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# To classify this email, I will go through the categories step by step:
#
# (A) Pre-sale question: This email is asking about the intended use of the Mixmaster 4000, which suggests it is a pre-sale question.
# (B) Broken or defective item: The email does not mention any issues with the Mixmaster 4000, so this category does not apply.
# (C) Billing question: The email does not mention any billing or payment-related questions, so this category does not apply.
# (D) Other: The email is asking a general question about the capabilities of the Mixmaster 4000, which does not fit into the other categories.
#
# Therefore, the correct answer is:
#
# <answer>A</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# User: Please classify this email into the following categories: I HAVE BEEN WAITING 4 MONTHS FOR MY MONTHLY CHARGES TO END AFTER CANCELLING!!  WTF IS GOING ON???
#
# Do not include any extra words except the category. Think step by step before you answer.
#
# <categories>
# (A) Pre-sale question
# (B) Broken or defective item
# (C) Billing question
# (D) Other (please explain)
# </categories>
#
# Answer with only the letter of the answer wrapped in <answer> tags, such as <answer>B</answer>.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# Based on the email content, the appropriate category is:
#
# <answer>C</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True
#
#
#
#
#
#
# --------------------------- Full prompt with variable substutions ---------------------------
# USER TURN
# User: Please classify this email into the following categories: How did I get here I am not good with computer.  Halp.
#
# Do not include any extra words except the category. Think step by step before you answer.
#
# <categories>
# (A) Pre-sale question
# (B) Broken or defective item
# (C) Billing question
# (D) Other (please explain)
# </categories>
#
# Answer with only the letter of the answer wrapped in <answer> tags, such as <answer>B</answer>.
#
# ASSISTANT TURN
#
#
# ------------------------------------- Claude's response -------------------------------------
# Analyzing the email content:
# - The user is expressing confusion and difficulty with using a computer, indicating a technical issue.
# - There is no mention of a purchase, billing, or a defective item.
#
# Based on the information provided, the most appropriate category is:
#
# <answer>D</answer>
#
# ------------------------------------------ GRADING ------------------------------------------
# This exercise has been correctly solved: True

# %% [markdown]
# ❓ If you want a hint, run the cell below!

# %%
from hints import exercise_6_2_hint; print(exercise_6_2_hint)

# %% [markdown]
# ### Congrats!
#
# If you've solved all exercises up until this point, you're ready to move to the next chapter. Happy prompting!

# %% [markdown]
# ---
#
# ## Example Playground
#
# This is an area for you to experiment freely with the prompt examples shown in this lesson and tweak prompts to see how it may affect Claude's responses.

# %%
# Prompt
PROMPT = """Is this movie review sentiment positive or negative?

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since the year 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %%
# System prompt
SYSTEM_PROMPT = "You are a savvy reader of movie reviews."

# Prompt
PROMPT = """Is this review sentiment positive or negative? First, write the best arguments for each side in <positive-argument> and <negative-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. In totally unrelated news, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT, SYSTEM_PROMPT))

# %%
# Prompt
PROMPT = """Is this review sentiment negative or positive? First write the best arguments for each side in <negative-argument> and <positive-argument> XML tags, then answer.

This movie blew my mind with its freshness and originality. Unrelatedly, I have been living under a rock since 1900."""

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956."

# Print Claude's response
print(get_completion(PROMPT))

# %%
# Prompt
PROMPT = "Name a famous movie starring an actor who was born in the year 1956. First brainstorm about some actors and their birth years in <brainstorm> tags, then give your answer."

# Print Claude's response
print(get_completion(PROMPT))
